# %% [markdown]
# 步骤:
# 寻找目标:和喜欢的女孩子搭讪并且夸她漂亮。
# 构建印象:玩舞拳/摇骰子，输的不止喝酒还要额外接受一个惩罚。
# 拉近关系:暴雨时找人亲吻，没找到的和酒。
# 转场宵夜:邀请观看猫咪后空翻。
# 开吃:

# %% [markdown]
# ## [土味情话](土味情话.md)

# %% [markdown]
# ## [游戏惩罚](游戏惩罚.md)

# %% [markdown]
# ## [外在提升](外在提升.md)
