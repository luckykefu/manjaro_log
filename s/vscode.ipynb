# %% [markdown]
# # vscode

# %%
# !pwd

# %% [markdown]
# ## plugins

# %% [markdown]
# ### Cursor 插件列表
#
# 当前已安装的 Cursor 插件：
#
# 1. **amazonwebservices.amazon-q-vscode** - Amazon Q AI 助手
# 3. **esbenp.prettier-vscode** - Prettier 代码格式化
# 4. **github.github-vscode-theme** - GitHub 主题
# 5. **ms-ceintl.vscode-language-pack-zh-hans** - 中文（简体）语言包
# 6. **ms-python.python** - Python 支持
# 7. **ms-toolsai.jupyter** - Jupyter 支持
# 9. **vscode-icons-team.vscode-icons** - 文件图标

# %% [markdown]
# ## 终端符号方块问题

# %%
# !echo "请在 Cursor 中设置终端字体：\n1. 打开 Cursor 设置 (Ctrl+, 或 Cmd+,)\n2. 搜索 'terminal font'\n3. 设置为以下字体之一：\n   - MesloLGS NF\n   - Hack Nerd Font Mono\n   - 或其他 Nerd Font 字体"
# Out:
# 请在 Cursor 中设置终端字体：
# 1. 打开 Cursor 设置 (Ctrl+, 或 Cmd+,)
# 2. 搜索 'terminal font'
# 3. 设置为以下字体之一：
#    - MesloLGS NF
#    - Hack Nerd Font Mono
#    - 或其他 Nerd Font 字体
