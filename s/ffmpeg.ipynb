# %% [markdown]
# ## 音频提取

# %%
# %%bash
# # 从视频提取音频
# ffmpeg -i "/home/lkf/Downloads/443714457-1-16.mp4" -vn -acodec copy output.aac
#
# # 转换为 MP3
# # ffmpeg -i input.mp4 -vn -ar 44100 -ac 2 -b:a 192k output.mp3
