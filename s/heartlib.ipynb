# %% [markdown]
# ## 内存不足

# %%
conda create -n heartlib python=3.10 ipykernel -y

# %%
# %%bash
# cd /data/projects
# export all_proxy="socks5://192.168.0.103:7897"
# git clone https://github.com/HeartMuLa/heartlib.git

# %%
# %cd /data/projects/heartlib
# %pip install -e .

# %%
# %pip uninstall torch torchvision torchaudio -y
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/rocm6.4

# %%
import torch
print(f"{torch.__version__=}")
print(f"{torch.cuda.is_available()=}")
print(f"{torch.cuda.get_device_name(0)=}" if torch.cuda.is_available() else "No GPU")

# %%
# %%bash
# cd /data/projects/heartlib
# modelscope download --model 'HeartMuLa/HeartMuLaGen' --local_dir './ckpt'
# modelscope download --model 'HeartMuLa/HeartMuLa-oss-3B' --local_dir './ckpt/HeartMuLa-oss-3B'
# modelscope download --model 'HeartMuLa/HeartCodec-oss' --local_dir './ckpt/HeartCodec-oss'

# %%
import torch
torch.cuda.empty_cache()

# %%
# %%bash
# cd /data/projects/heartlib
# HSA_OVERRIDE_GFX_VERSION=10.3.0 python ./examples/run_music_generation.py --model_path=./ckpt  --lazy_load true --version="3B"
# Out:
# Model components will be loaded to devices as specified:
#   mula: cuda
#   codec: cuda
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s]
# Traceback (most recent call last):
#   File "/data/projects/heartlib/./examples/run_music_generation.py", line 70, in <module>
#     pipe(
#   File "/data/projects/heartlib/src/heartlib/pipelines/music_generation.py", line 349, in __call__
#     model_outputs = self._forward(model_inputs, **forward_kwargs)
#   File "/data/projects/heartlib/src/heartlib/pipelines/music_generation.py", line 283, in _forward
#     self.mula.setup_caches(bs_size)
#   File "/data/projects/heartlib/src/heartlib/heartmula/modeling_heartmula.py", line 165, in setup_caches
#     self.backbone.setup_caches(max_batch_size, dtype)
#   File "/data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/torchtune/modules/transformer.py", line 444, in setup_caches
#     layer.setup_caches(
#   File "/data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/torchtune/modules/transformer.py", line 64, in setup_caches
#     self.attn.setup_cache(batch_size, dtype, max_seq_len=decoder_max_seq_len)
#   File "/data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/torchtune/modules/attention.py", line 164, in setup_cache
#     self.kv_cache = KVCache(
#   File "/data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/torchtune/modules/kv_cache.py", line 41, in __init__
#     "v_cache", torch.zeros(cache_shape, dtype=dtype), persistent=False
#   File "/data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/torch/utils/_device.py", line 103, in __torch_function__
#     return func(*args, **kwargs)
# torch.OutOfMemoryError: HIP out of memory. Tried to allocate 96.00 MiB. GPU 0 has a total capacity of 11.98 GiB of which 40.00 MiB is free. Of the allocated memory 11.75 GiB is allocated by PyTorch, and 10.16 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd /data/projects/heartlib\nHSA_OVERRIDE_GFX_VERSION=10.3.0 python ./examples/run_music_generation.py --model_path=./ckpt  --lazy_load true --version="3B"\n')
#
# File /data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/IPython/core/magics/script.py:154, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     152 else:
#     153     line = script
# --> 154 return self.shebang(line, cell)
#
# File /data/.path/.miniconda3/envs/heartlib/lib/python3.10/site-packages/IPython/core/magics/script.py:314, in ScriptMagics.shebang(self, line, cell)
#     309 if args.raise_error and p.returncode != 0:
#     310     # If we get here and p.returncode is still None, we must have
#     311     # killed it but not yet seen its return code. We don't wait for it,
#     312     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     313     rc = p.returncode or -9
# --> 314     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'cd /data/projects/heartlib\nHSA_OVERRIDE_GFX_VERSION=10.3.0 python ./examples/run_music_generation.py --model_path=./ckpt  --lazy_load true --version="3B"\n'' returned non-zero exit status 1.
