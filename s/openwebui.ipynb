# %% [markdown]
# ## 安装

# %%
conda create --name openwebui python=3.11 ipykernel -y

# %%
# %pip install open-webui

# %% [markdown]
# ## mcp

# %%
# %pip install mcpo

# %%
# %%bash
# export HF_HUB_OFFLINE=1
# open-webui serve

# %%
mcpo --port 8000 --api-key "top-secret" -- uvx mcp-server-time --local-timezone=Asia/Shanghai

# %%
mcpo --config /path/to/config.json --hot-reload
