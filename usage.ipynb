# %% [markdown]
# ## 软件数据无法迁移
#
# ## 和密码有关的全部交互式输入
#
# ## 保持简单

# %% [markdown]
# ## [sys_basic_cfg](./src/sys_basic_cfg.ipynb)

# %% [markdown]
# ## update

# %%
# %%bash
# bash reinstall_system/006_update.sh
# Out:
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Starting full system upgrade...
#  there is nothing to do
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Searching AUR for updates...
# :: Searching databases for updates...
#  -> Packages not in AUR: libkcompactdisc
#  there is nothing to do
