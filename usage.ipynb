# %% [markdown]
# ## 软件数据无法迁移
#
# ## 和密码有关的全部交互式输入
#
# ## 保持简单

# %% [markdown]
# ## [sys_basic_cfg](./src/sys_basic_cfg.ipynb)

# %% [markdown]
# ## update

# %%
# %%bash
# bash reinstall_system/006_update.sh
# Out:
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Starting full system upgrade...
# resolving dependencies...
# looking for conflicting packages...
#
# Packages (2) kwin-6.6.4-1.0  manjaro-hello-0.8.1-5
#
# Total Download Size:   12.03 MiB
# Total Installed Size:  30.84 MiB
# Net Upgrade Size:       0.04 MiB
#
# :: Proceed with installation? [Y/n]
# :: Retrieving packages...
#  kwin-6.6.4-1.0-x86_64 downloading...
#  manjaro-hello-0.8.1-5-any downloading...
# checking keyring...
# checking package integrity...
# loading package files...
# checking for file conflicts...
# checking available disk space...
# :: Processing package changes...
# upgrading kwin...
# upgrading manjaro-hello...
# :: Running post-transaction hooks...
# (1/4) Reloading user manager configuration...
# (2/4) Arming ConditionNeedsUpdate...
# (3/4) Updating icon theme caches...
# (4/4) Updating the desktop file MIME type cache...
# ...
