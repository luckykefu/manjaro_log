# %% [markdown]
# ## 软件数据无法迁移
#
# ## 和密码有关的全部交互式输入
#
# ## 保持简单

# %% [markdown]
# ## [sys_basic_cfg](./src/sys_basic_cfg.ipynb)

# %% [markdown]
# ## update

# %%
# %%bash
# # sudo pacman-mirrors --country China
# sudo pacman -Syyu --noconfirm
# yay -Syyu --noconfirm
# Out:
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Starting full system upgrade...
#  there is nothing to do
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Searching AUR for updates...
# :: Searching databases for updates...
#  -> Flagged Out Of Date AUR Packages: visual-studio-code-bin
#  there is nothing to do

# %% [markdown]
# ## 密码 生成

# %%
# %%bash
# d="$HOME/.local/share/Cryptomator/mnt/cryptomator"
# script=$(find "$d" -type f -name "gen_secret.sh" -print -quit) && source "$script"
# cd "$d" || exit
# gen_secret "appflowy"
