# %% [markdown]
# ## 软件数据无法迁移
#
# ## 和密码有关的全部交互式输入
#
# ## 简单是最好的

# %% [markdown]
# ## [sys_basic_cfg](./src/sys_basic_cfg.ipynb)

# %% [markdown]
# ## update

# %%
# %%bash
# # sudo pacman-mirrors --country China
# sudo pacman -Syyu --noconfirm
# yay -Syyu --noconfirm
# Out:
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Starting full system upgrade...
# resolving dependencies...
# looking for conflicting packages...
#
# Packages (1) ventoy-1.1.12-1
#
# Total Download Size:   16.10 MiB
# Total Installed Size:  19.00 MiB
# Net Upgrade Size:       0.00 MiB
#
# :: Proceed with installation? [Y/n]
# :: Retrieving packages...
#  ventoy-1.1.12-1-x86_64 downloading...
# checking keyring...
# checking package integrity...
# loading package files...
# checking for file conflicts...
# checking available disk space...
# :: Processing package changes...
# upgrading ventoy...
# :: Running post-transaction hooks...
# (1/2) Arming ConditionNeedsUpdate...
# (2/2) Updating the desktop file MIME type cache...
# :: Synchronizing package databases...
#  core downloading...
#  extra downloading...
#  multilib downloading...
# :: Searching AUR for updates...
# :: Searching databases for updates...
#  there is nothing to do

# %% [markdown]
# ## 密码 生成

# %%
# %%bash
# d="$HOME/.local/share/Cryptomator/mnt/cryptomator"
# script=$(find "$d" -type f -name "gen_secret.sh" -print -quit) && source "$script"
# cd "$d" || exit
# gen_secret "appflowy"
