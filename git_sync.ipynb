# %% [markdown]
# # git sync

# %%
# %pip install pygithub

# %%
# 添加..utils到sys.path
import sys
import os
sys.path.append(os.path.abspath("/data/projects_ING/crypto_quant/.manjaro/utils"))
from git_sync import git_sync
git_sync(".", "Update notebook")
# Out:
# [main 9486865] Update notebook
#  53 files changed, 19832 insertions(+), 1436 deletions(-)
#  delete mode 100644 001.code-workspace
#  create mode 100755 config/config.yaml
#  delete mode 100755 s/ollama.ipynb
#  rename {s => src}/TikTokDownloader.ipynb (100%)
#  create mode 100644 src/TradingAgents-CN.ipynb
#  create mode 100644 src/TradingAgents.ipynb
#  create mode 100755 src/amazonq.ipynb
#  rename {s => src}/clash.ipynb (100%)
#  rename {s => src}/docker.ipynb (100%)
#  rename {s => src}/ffmpeg.ipynb (100%)
#  create mode 100644 "src/gradio\345\205\250\351\235\242\346\225\231\347\250\213.ipynb"
#  rename {s => src}/heartlib.ipynb (100%)
#  rename {s => src}/kde_cfg.ipynb (100%)
#  create mode 100644 src/neovim.ipynb
#  create mode 100755 src/ollama.ipynb
#  rename {s => src}/opencode.ipynb (100%)
#  rename {s => src}/openrouter.ipynb (100%)
#  rename {s => src}/openwebui.ipynb (100%)
#  create mode 100644 src/plotly.ipynb
#  rename {s => src}/secure_usb.ipynb (100%)
#  rename {s => src}/soft_basic.ipynb (100%)
#  rename {s => src}/software.ipynb (100%)
#  rename {s => src}/sys_basic_cfg.ipynb (100%)
#  create mode 100644 src/ta-lib.ipynb
#  rename {s => src}/vscode.ipynb (100%)
#  rename {s => src}/whisper.ipynb (100%)
#  create mode 100644 utils/__init__.py
#  create mode 100644 utils/__pycache__/add_path_to_rc.cpython-314.pyc
#  delete mode 100755 utils/__pycache__/clash.cpython-313.pyc
#  create mode 100644 utils/__pycache__/config.cpython-314.pyc
#  create mode 100644 utils/__pycache__/create_symlink.cpython-314.pyc
#  create mode 100644 utils/__pycache__/github_downloader.cpython-314.pyc
#  create mode 100644 utils/__pycache__/openrouterai.cpython-314.pyc
#  delete mode 100644 utils/__pycache__/whisper.cpython-314.pyc
#  delete mode 100644 utils/__pycache__/whisper_tool.cpython-314.pyc
#  create mode 100644 utils/add_path_to_rc.py
#  delete mode 100755 utils/clash.py
#  delete mode 100755 utils/clean.sh
#  delete mode 100755 utils/clone_create_conda_env.sh
#  create mode 100755 utils/config.py
#  delete mode 100755 utils/create_ipynb.sh
#  delete mode 100755 utils/create_secure_usb.sh
#  delete mode 100644 utils/create_snapshots.sh
#  create mode 100644 utils/create_symlink.py
#  create mode 100644 utils/github_downloader.py
#  create mode 100644 utils/github_tools.py
#  delete mode 100755 utils/install_and_start_wine.sh
#  create mode 100644 utils/ollama.py
#  create mode 100644 utils/openrouterai.py
#  delete mode 100755 utils/shadowsocks_server_conf.sh
#  delete mode 100755 utils/sync_repo.sh
# To github.com:luckykefu/manjaro_log.git
#    db197c7..9486865  main -> main

# %%
# %%bash
# d="/data/.cryptomator"
# ./find_and_run.sh . sync_repo.sh "$d"
