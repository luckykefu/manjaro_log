# %% [markdown]
# # git sync

# %%
# %pip install pygithub

# %%
# %cd /data/.manjaro
# Out:
# /data/.manjaro

# %%
# 添加..utils到sys.path
from utils.git_sync import git_sync


git_sync(".", "Update notebook")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /data/.manjaro/utils/git_sync.py:12
#      11 try:
# ---> 12     from config import logger
#      13 except ImportError:
#
# ModuleNotFoundError: No module named 'config'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /data/.manjaro/utils/config.py:27, in Config._load_config(self)
#      26 try:
# ---> 27     with open(config_path, encoding="utf-8") as f:
#      28         return yaml.safe_load(f) or {}
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/.manjaro/config/config.yaml'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 添加..utils到sys.path
# ...

# %%
d="/data/.cryptomator"
git_sync(d, "Update notebook")
