# %% [markdown]
# # git sync

# %%
# %pip install pygithub

# %%
# 添加..utils到sys.path
import sys
import os
sys.path.append(os.path.abspath("/data/projects_ING/crypto_quant/.manjaro/utils"))
from git_sync import git_sync
git_sync(".", "Update notebook")
# Out:
# [01/27/26 16:01:52] INFO     Logger Initialized: app at level DEBUG                                    ]8;id=196080;file:///data/projects_ING/crypto_quant/.manjaro/utils/config.py\config.py]8;;\:]8;id=714023;file:///data/projects_ING/crypto_quant/.manjaro/utils/config.py#78\78]8;;\
#                     DEBUG    repo_path='.', commit_msg='Update notebook'                             ]8;id=712659;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py\git_sync.py]8;;\:]8;id=156688;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py#24\24]8;;\
# [main cf2d70e] Update notebook
#  5 files changed, 111 insertions(+), 68 deletions(-)
#  create mode 100644 utils/__pycache__/git_sync.cpython-314.pyc
#  create mode 100644 utils/git_sync.py
#  delete mode 100644 utils/github_tools.py
# To github.com:luckykefu/manjaro_log.git
#    9486865..cf2d70e  main -> main
# [01/27/26 16:01:55] INFO     Git sync completed successfully                                         ]8;id=96875;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py\git_sync.py]8;;\:]8;id=940420;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py#32\32]8;;\
# True

# %%
# %%bash
# d="/data/.cryptomator"
# ./find_and_run.sh . sync_repo.sh "$d"
