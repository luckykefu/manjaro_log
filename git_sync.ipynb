# %% [markdown]
# # git sync

# %%
# %%bash
# rm -rf .git
# git init
# git remote add origin git@github.com:luckykefu/manjaro_log.git

# %%
# %%bash
# git add ./backup
# git commit -m "first commit to add backup dir"
# git push -u origin main

# %%
# %%bash
# mkdir -p system_basic_config/utils
# git add ./system_basic_config
# git commit -m "add system_basic_config dir"
# git push

# %%
# %%bash
# mkdir -p kde_config/utils
# git add ./kde_config
# git commit -m "add kde_config dir"
# git push

# %%
# %%bash
# mkdir -p software_basic_config/utils
# git add ./software_basic_config
# git commit -m "add software_basic_config dir"
# git push

# %%
# %%bash
# ./find_and_run.sh sync_repo.sh
# Out:
# Running ./utils/sync_repo.sh -> sync_repo
# [main eabdcfd] update 2026-01-07T14:03:48+08:00
#  36 files changed, 5974 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100755 000_sudo_nopassword.sh
#  create mode 100644 backup/ZeroOmegaOptions-2025-12-07T01_51_03.631Z.bak
#  create mode 100644 backup/keepassxc-cfg.ini
#  create mode 100755 find_and_run.sh
#  create mode 100644 git_sync.ipynb
#  create mode 100644 kde_config/kde_cfg.sh
#  create mode 100644 kde_config/utils/install_dolphin_vscode.sh
#  create mode 100644 kde_config/utils/install_themes.sh
#  create mode 100644 kde_config/utils/wallpaper_conf.sh
#  create mode 100644 "ref_doc/jupter\351\255\224\346\263\225\345\221\275\344\273\244\344\275\277\347\224\250\347\244\272\344\276\213.ipynb"
#  create mode 100644 ref_doc/suno-music.ipynb
#  create mode 100644 "ref_doc/\346\267\267\351\237\263.ipynb"
# ...

# %%
# %%bash
# d="/data/.cryptomator"
# script=$(find . -type f -name "sync_repo.sh" -print -quit) && source "$script"
# cd "$d" || exit
# sync_repo "$d"
