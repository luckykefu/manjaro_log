# %% [markdown]
# # git sync

# %%
# %%bash
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 97a682b] sss
#  1 file changed, 54 insertions(+), 4 deletions(-)
# ssh_askpass: exec(/usr/lib/ssh/ssh-askpass): No such file or directory
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git add .\ngit commit -m "sss"\ngit push\n')
#
# File /data/.manjaro/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
# ...

# %%
d="/data/.cryptomator"
