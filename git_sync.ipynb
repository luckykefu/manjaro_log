# %% [markdown]
# # git sync

# %%
# %pip install pygithub

# %%
# 添加..utils到sys.path
import sys
import os
sys.path.append(os.path.abspath("/data/projects_ING/crypto_quant/.manjaro/utils"))
from git_sync import git_sync
git_sync(".", "Update notebook")
# Out:
# [01/27/26 16:02:10] DEBUG    repo_path='.', commit_msg='Update notebook'                             ]8;id=315994;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py\git_sync.py]8;;\:]8;id=115090;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py#24\24]8;;\
# [main 1ae9a49] Update notebook
#  1 file changed, 56 insertions(+), 55 deletions(-)
# To github.com:luckykefu/manjaro_log.git
#    cf2d70e..1ae9a49  main -> main
# [01/27/26 16:02:13] INFO     Git sync completed successfully                                         ]8;id=356048;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py\git_sync.py]8;;\:]8;id=184762;file:///data/projects_ING/crypto_quant/.manjaro/utils/git_sync.py#32\32]8;;\
# True

# %%
# %%bash
# d="/data/.cryptomator"
# ./find_and_run.sh . sync_repo.sh "$d"
