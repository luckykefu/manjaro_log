# %% [markdown]
# # git sync

# %%
# %%bash
# rm -rf .git
# git init
# git remote add origin git@github.com:luckykefu/manjaro_log.git

# %%
# %%bash
# git add ./backup
# git commit -m "first commit to add backup dir"
# git push -u origin main

# %%
# %%bash
# mkdir -p system_basic_config/utils
# git add ./system_basic_config
# git commit -m "add system_basic_config dir"
# git push

# %%
# %%bash
# mkdir -p kde_config/utils
# git add ./kde_config
# git commit -m "add kde_config dir"
# git push

# %%
# %%bash
# mkdir -p software_basic_config/utils
# git add ./software_basic_config
# git commit -m "add software_basic_config dir"
# git push

# %%
# %%bash
# ./find_and_run.sh . sync_repo.sh
# Out:
# Running ./utils/sync_repo.sh -> sync_repo
# [main 64f9d5b] update 2026-01-08T19:09:34+08:00
#  11 files changed, 1149 insertions(+), 171 deletions(-)
#  create mode 120000 .amazonq
#  create mode 100644 backup_data/keepassxc-browser_settings.json
#  create mode 100644 s/TikTokDownloader.ipynb
#  create mode 100644 s/ollama.ipynb
#  create mode 100644 s/whisper.ipynb
#  create mode 100644 utils/clone_create_conda_env.sh
#  create mode 100644 utils/create_ipynb.sh
# To github.com:luckykefu/manjaro_log.git
#    3bca156..64f9d5b  main -> main

# %%
# %%bash
# d="/data/.cryptomator"
# ./find_and_run.sh . sync_repo.sh "$d"
# Out:
# Running ./utils/sync_repo.sh -> sync_repo
# [main 03816bc] update 2026-01-08T19:10:16+08:00
#  1 file changed, 0 insertions(+), 0 deletions(-)
# To github.com:luckykefu/cryptomator.git
#    062e9ec..03816bc  main -> main
