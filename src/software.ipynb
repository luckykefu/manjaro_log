# %% [markdown]
# ## [vscode plugins](vscode.ipynb)

# %% [markdown]
# ## [VirtualBox](VirtualBox.ipynb)

# %% [markdown]
# ## 步骤3: 安装 [Docker](docker.ipynb)

# %% [markdown]
# ## 步骤5: 安装 [Miniconda3](miniconda3.ipynb)

# %% [markdown]
# ## 步骤6: 安装 [Ardour](ardour.ipynb)

# %% [markdown]
# ## 步骤7: 安装 [zsh-sudo](zsh-sudo.ipynb) 插件

# %% [markdown]
# ## 步骤13: 安装 [Wine](wine.ipynb)

# %% [markdown]
# ## [chrome](chrome.ipynb)

# %% [markdown]
# ## [clash](clash.ipynb)

# %% [markdown]
# ## [Davinci Resolve](Davinci_Resolve.ipynb)
#
# https://www.blackmagicdesign.com/products/davinciresolve/

# %% [markdown]
# ## [ollama](ollama.ipynb)

# %% [markdown]
# ## [waydroid](waydroid.ipynb)

# %% [markdown]
# ## [wine](wine.ipynb)

# %% [markdown]
# ## [yabridge](yabridge.ipynb)
