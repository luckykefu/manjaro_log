# %%
# %cd /data/.manjaro
# Out:
# /data/.manjaro

# %%
# %%writefile .amazonq/rules/rules.md
# # 使用中文进行对话
#
# ## 编程环境
#
# - CPU: Intel 12400F
# - GPU: AMD 6750 GRE 12G
# - 系统: Linux Arch Manjaro
# - 终端: zsh
#
# ## 代理配置
#
# - Python: `socks5h://192.168.0.103:7897`
#
# ## Python 规则
#
# - pylance 标准编程
# - **类型提示**：必须使用 Python 的 Type Hints (typing 模块)
# - **错误处理**：需要包含完整的 try-except 块，妥善处理 [特定的错误，如网络超时、文件不存在]
# - **代码风格**：遵循 PEP 8，变量命名清晰。重试机制,缓存机制,
#
# ## Shell 命令
#
# ```bash
# # 安装包
# sudo pacman -S --needed --noconfirm pkg
#
# ```
#
# ## 日志规范
#
# - 参数验证使用 `logger.debug(f"{msg=}")`
# - 返回结果使用 `logger.info(f"{msg=}")`
# - 异常错误使用 `logger.error(f"{msg=}")`
#
# ## 代码结构
#
# - 使用注释分隔符标记代码块：`# [ 标题 ]`
# - 标准代码块顺序：参数验证 → 业务逻辑 → 返回结果
#
# ## Python 文件模板
#
# ```python
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
# """
# # [ 模块功能介绍 ]
#
# """
#
# from config import config,logger
#
#
# def example_function(param1: str, param2: int) -> None:
#     """
#     示例函数
#     :params:
#         :param1: 参数1说明
#         :param2: 参数2说明
#     :return: 返回值说明
#     """
#     # [ 参数验证 ]
#     logger.debug(f"{param1=}, {param2=}")
#
#     # [ 业务逻辑 ]
#     result = None
#
#     # [ 返回结果 ]
#     logger.info(f"{result=}")
#     return result
#
#
# if __name__ == "__main__":
#     # [ 使用示例 ]
#     example_function(param1="test", param2=123)
# ```
#
# ## 项目结构
#
# ```
# project/
# ├── config/
#     └────── config.yaml # 配置文件
# ├── utils/              # 工具函数
#     ├────── __init__.py
#     └───────config.py
# ```
# Out:
# Overwriting .amazonq/rules/rules.md

# %% [markdown]
# ## 登录凭证

# %%
# !rm -rf $(realpath "$HOME/.aws/sso") $(realpath "active-user-state.json")

# %%
# %%bash
# today=`date +%y-%m-%d-%T`
# echo $today
# Out:
# 26-01-31-17:57:10

# %% [markdown]
# 已达限制:
# | 账号 | 时间 |
# | --- | --- |
# |19157521820@163.com|2026-01-08 12:31:30|
# |3t9k47mwk@mozmail.com|2026-01-11 12:02:31|
# |rnkx9papw@mozmail.com|2026-01-17 16:05:47|
# |kefu1820@gmail.com |26-01-21-21:20:15|
# |p75rtna4c@mozmail.com|26-01-26-15:48:57|
# |gty2a7jb9@mozmail.com||
# |koofuluo@gmail.com|26-01-26-22:33:02|
# |fcfwb7cs6@mozmail.com|26-01-31-17:57:10|
# |okl7ne8tn@mozmail.com||

# %%
"""
认证失败:
5umv6t7y5@mozmail.com
kefu51252@gamil.com
"""

# %% [markdown]
# ---
#
# # Amazon Q Developer 全面使用教程

# %% [markdown]
# ## 一、核心功能
#
# ### 1. 代码生成
#
# - 自然语言 → 代码
# - 支持多种语言
# - 上下文感知
#
# ### 2. 代码补全
#
# - 实时建议
# - 多行补全
# - 智能预测
#
# ### 3. 代码解释
#
# - 解释复杂代码
# - 文档生成
# - 注释添加
#
# ### 4. 代码优化
#
# - 性能优化
# - 安全扫描
# - 最佳实践
#
# ### 5. 测试生成
#
# - 单元测试
# - 集成测试
# - 测试用例

# %% [markdown]
# ## 二、斜杠命令详解
#
# ### /dev - 开发新功能
#
# ```
# 用途: 实现新功能
# 示例: /dev 实现一个数据缓存功能
#
# 流程:
# 1. 分析需求
# 2. 设计方案
# 3. 生成代码
# 4. 创建文件
# ```
#
# ### /test - 生成测试
#
# ```
# 用途: 为代码生成测试
# 示例: /test 为 MaxPainFetcher 类生成单元测试
#
# 生成:
# - 单元测试
# - Mock 数据
# - 边界测试
# - 异常测试
# ```
#
# ### /review - 代码审查
#
# ```
# 用途: 审查代码质量
# 示例: /review @strategys/
#
# 检查:
# - 代码规范
# - 安全漏洞
# - 性能问题
# - 最佳实践
# ```
#
# ### /doc - 生成文档
#
# ```
# 用途: 生成文档
# 示例: /doc 为这个函数生成文档
# ```
#
# ### /fix - 修复问题
#
# ```
# 用途: 修复代码问题
# 示例: /fix 修复这个 bug
# ```
#
# ### /transform - 代码转换
#
# ```
# 用途: 转换代码
# 示例: /transform 将这段代码转换为 TypeScript
# ```

# %% [markdown]
# ## 三、上下文引用
#
# ### @file - 引用文件
#
# ```
# 用法: @config.py
# 作用: 将文件内容加入上下文
# ```
#
# ### @folder - 引用文件夹
#
# ```
# 用法: @strategys/
# 作用: 将文件夹所有文件加入上下文
# ```
#
# ### @workspace - 引用工作区
#
# ```
# 用法: @workspace
# 作用: 智能选择相关文件
# ```
#
# ### @prompt - 引用提示词
#
# ```
# 用法: @prompt_name
# 作用: 使用保存的提示词模板
# 位置: ~/.aws/amazonq/prompts/
# ```

# %% [markdown]
# ## 四、最佳实践
#
# ### 1. 清晰的需求描述
#
# ```
# ❌ 差: 写个函数
# ✅ 好: 写一个函数，接收 BTC 价格列表，计算 SMA(20)
# ```
#
# ### 2. 提供上下文
#
# ```
# ❌ 差: 优化这段代码
# ✅ 好: @config.py 优化配置加载性能
# ```
#
# ### 3. 分步骤执行
#
# ```
# ❌ 差: 实现完整的交易系统
# ✅ 好:
#   1. /dev 实现数据采集模块
#   2. /dev 实现策略计算模块
#   3. /dev 实现订单执行模块
# ```
#
# ### 4. 验证结果
#
# ```
# 生成代码后:
# 1. /test 生成测试
# 2. /review 代码审查
# 3. 手动测试
# ```

# %% [markdown]
# ## 五、实战示例
#
# ### 示例1: 开发新功能
#
# ```
# 需求: 实现订单簿数据采集
#
# 步骤:
# 1. /dev 实现订单簿数据采集功能
#    - 使用 ccxt 库
#    - 支持 Binance 交易所
#    - 返回 DataFrame 格式
#
# 2. /test 为 OrderBookCollector 生成测试
#
# 3. /review @data/collector.py
# ```
#
# ### 示例2: 代码优化
#
# ```
# 需求: 优化配置加载
#
# 步骤:
# 1. @config.py 分析这个配置加载代码的性能问题
#
# 2. /fix 优化配置加载性能
#    - 添加缓存
#    - 延迟加载
#    - 减少 I/O
#
# 3. /test 生成性能测试
# ```
#
# ### 示例3: 代码审查
#
# ```
# 需求: 审查策略代码
#
# 步骤:
# 1. /review @strategys/ 检查以下方面:
#    - 代码规范
#    - 安全问题
#    - 性能优化
#    - 错误处理
#
# 2. 根据建议修改
#
# 3. /test 补充测试用例
# ```

# %% [markdown]
# ## 六、高级技巧
#
# ### 1. 自定义提示词
#
# ```bash
# # 创建提示词文件
# mkdir -p ~/.aws/amazonq/prompts/
# cat > ~/.aws/amazonq/prompts/trading_style.md << 'EOF'
# # 交易代码风格
# - 使用类型注解
# - 添加日志记录
# - 异常处理完善
# - 遵循 PEP 8
# EOF
#
# # 使用
# @trading_style /dev 实现策略
# ```
#
# ### 2. 项目级规则
#
# ```bash
# # 创建规则文件
# mkdir -p .amazonq/rules/
# cat > .amazonq/rules/rules.md << 'EOF'
# # 项目规则
# - 使用中文注释
# - 配置使用 YAML
# - 日志使用 Rich
# EOF
#
# # 自动应用到所有对话
# ```
#
# ### 3. 多文件操作
#
# ```
# # 同时引用多个文件
# @config.py @utils.py @strategy.py
# 重构这些模块的依赖关系
# ```
#
# ### 4. 增量开发
#
# ```
# # 第一步
# /dev 实现基础框架
#
# # 第二步
# @framework.py /dev 添加错误处理
#
# # 第三步
# @framework.py /dev 添加日志记录
#
# # 第四步
# @framework.py /test 生成完整测试
# ```

# %% [markdown]
# ## 七、快速参考
#
# ### 常用命令
#
# ```
# /dev    - 开发新功能
# /test   - 生成测试
# /review - 代码审查
# /doc    - 生成文档
# /fix    - 修复问题
# /transform - 代码转换
# ```
#
# ### 上下文引用
#
# ```
# @file      - 引用文件
# @folder    - 引用文件夹
# @workspace - 引用工作区
# @prompt    - 引用提示词
# ```
#
# ### 快捷键
#
# ```
# Alt+C / Option+C - 触发代码补全
# Ctrl+I - 打开内联聊天
# ```
#
# ### 工作流
#
# ```
# 1. 需求分析
# 2. /dev 生成代码
# 3. /test 生成测试
# 4. /review 代码审查
# 5. 手动验证
# 6. 部署上线
# ```
