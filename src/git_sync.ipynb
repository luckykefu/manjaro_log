# %% [markdown]
# # git sync

# %%
# %%bash
# ssh-keyscan github.com >> ~/.ssh/known_hosts 2>/dev/null
# d="/data/.manjaro"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 024a93a] sss
#  18 files changed, 1993 insertions(+), 47 deletions(-)
#  rename .amazonq/rules/{s.md => rules.md} (100%)
#  create mode 100644 "docs/CBT\346\240\270\345\277\203\347\226\227\346\263\225.md"
#  create mode 100644 docs/hippop.ipynb
#  create mode 100644 "docs/\345\234\237\345\221\263\346\203\205\350\257\235.md"
#  create mode 100644 "docs/\345\244\226\345\234\250\346\217\220\345\215\207.md"
#  create mode 100644 "docs/\346\210\221\347\232\204\344\270\200\347\224\237.md"
#  create mode 100644 "docs/\346\270\270\346\210\217\346\203\251\347\275\232.md"
#  create mode 100644 "docs/\351\205\222\345\220\247\346\224\273\347\225\245.ipynb"
#  create mode 100644 src/fcixt5.ipynb
# To github.com:luckykefu/manjaro_log.git
#    ef8ea9a..024a93a  main -> main

# %%
# %%bash
# d="/data/.cryptomator"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 04a9f01] sss
#  1 file changed, 0 insertions(+), 0 deletions(-)
# To github.com:luckykefu/cryptomator.git
#    3d12b46..04a9f01  main -> main
