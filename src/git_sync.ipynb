# %% [markdown]
# # git sync

# %%
# %%bash
# ssh-keyscan github.com >> ~/.ssh/known_hosts 2>/dev/null
# d="/data/.manjaro"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 04023d3] sss
#  14 files changed, 106 insertions(+), 1258 deletions(-)
#  rename .blackboxrules => .amazonq/rules/s.md (89%)
#  delete mode 100755 git_sync.ipynb
#  delete mode 100644 mcp/fredapi-mcp/.python-version
#  delete mode 100644 mcp/fredapi-mcp/README.md
#  delete mode 100644 mcp/fredapi-mcp/fred_server.py
#  delete mode 100644 mcp/fredapi-mcp/main.py
#  delete mode 100644 mcp/fredapi-mcp/pyproject.toml
#  delete mode 100644 mcp/fredapi-mcp/uv.lock
#  create mode 100755 src/git_sync.ipynb
#  delete mode 100644 utils/add_path_to_rc.py
#  delete mode 100644 utils/git_sync.py
#  delete mode 100644 utils/gpg_manager.py
#  delete mode 100644 utils/yay_manager.py
# To github.com:luckykefu/manjaro_log.git
#    1406561..04023d3  main -> main

# %%
# %%bash
# d="/data/.cryptomator"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 04a9f01] sss
#  1 file changed, 0 insertions(+), 0 deletions(-)
# To github.com:luckykefu/cryptomator.git
#    3d12b46..04a9f01  main -> main
