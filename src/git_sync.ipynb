# %% [markdown]
# # git sync

# %%
# %%bash
# ssh-keyscan github.com >> ~/.ssh/known_hosts 2>/dev/null
# d="/data/.manjaro"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main ef8ea9a] sss
#  11 files changed, 202 insertions(+), 113 deletions(-)
#  delete mode 100755 find_and_run.sh
#  create mode 100644 src/crontab.ipynb
#  create mode 100644 src/set_utc.ipynb
#  delete mode 100755 src/soft_basic.ipynb
#  delete mode 100644 utils/ollama.py
# To github.com:luckykefu/manjaro_log.git
#    04023d3..ef8ea9a  main -> main

# %%
# %%bash
# d="/data/.cryptomator"
# cd $d
# git add .
# git commit -m "sss"
# git push
# Out:
# [main 04a9f01] sss
#  1 file changed, 0 insertions(+), 0 deletions(-)
# To github.com:luckykefu/cryptomator.git
#    3d12b46..04a9f01  main -> main
