# %%
# download
# urls="https://code.visualstudio.com/sha/download?build=stable&os=linux-x64"
# tar -xzvf *.tar.gz && rm -fr *.tar.gz 

# 3124568493@qq.com

# %% [markdown]
# ## plugins

# %%
# %%bash
# code --list-extensions

# %% [markdown]
# ## 终端符号方块问题

# %%
"""请在  中设置终端字体：
1. 打开  设置 (Ctrl+, 或 Cmd+,)
2. 搜索 'terminal font'
3. 设置为以下字体之一：
   - MesloLGS NF
   - Hack Nerd Font Mono
   - 或其他 Nerd Font 字体
"""
