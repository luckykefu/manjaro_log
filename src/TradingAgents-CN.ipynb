# %% [markdown]
# ## 克隆项目

# %%
# %cd /data/projects_ING

# %%
# !git clone https://github.com/hsliuping/TradingAgents-CN.git
# %cd TradingAgents-CN

# %% [markdown]
# ## 安装 MongoDB

# %%
# %%bash
# yay -S --needed --noconfirm mongodb mongodb-tools

# %% [markdown]
# ### 启动 MongoDB

# %%
# %%bash
# sudo systemctl start mongodb
# # sudo systemctl enable mongodb

# %% [markdown]
# ### 验证 MongoDB

# %%
# %%bash
# sudo systemctl status mongodb

# %% [markdown]
# ## 安装 Redis

# %%
# %%bash
# sudo pacman -S --needed --noconfirm redis

# %% [markdown]
# ### 启动 Redis

# %%
# %%bash
# sudo systemctl start redis
# # sudo systemctl enable redis

# %% [markdown]
# ### 验证 Redis

# %%
# %%bash
# redis-cli ping

# %% [markdown]
# ## 配置conda环境

# %%
# %%bash
# conda env list | grep -q "^TradingAgentsCN " || conda create --name TradingAgentsCN python=3.12 ipykernel pysocks -y

# %% [markdown]
# ### 安装依赖

# %%
# %cd /data/projects_ING/TradingAgents-CN
# %pip install -r requirements.txt

# %%
# !cp .env.example .env

# %%
# %%bash
# cat > .env << 'EOL'
# # 数据库配置（参考docker-compose.hub.nginx.yml中的配置）
# MONGODB_URL=mongodb://admin:tradingagents123@localhost:27017/tradingagents?authSource=admin
# REDIS_URL=redis://:tradingagents123@localhost:6379/0
#
# # API 配置
# API_BASE_URL=http://localhost:8000
# CORS_ORIGINS=["http://localhost:3000"]
#
# # LLM 配置（根据需要配置）
# OPENAI_API_KEY=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
# DEEPSEEK_API_KEY=sk-de79dba429344ae18f5b6fca0d885e3b
# SILICONFLOW_API_KEY=sk-uvgwqnjcxvjouwaokpnksjtohlrxvlkvhevpnpcncnucwmgy
#
# # 其他配置
# DEBUG=true
# LOG_LEVEL=INFO
# EOL

# %%
# %cd frontend
# !npm install

# %%
# !sudo systemctl status mongod  # Linux
# !sudo systemctl status redis  # Linux

# %%
# %cd /data/projects_ING/TradingAgents-CN
# Out:
# /data/projects_ING/TradingAgents-CN

# %%
# %%bash
# # 连接MongoDB（使用管理员账户）
# mongosh mongodb://admin:tradingagents123@localhost:27017/admin
#
# # 切换到tradingagents数据库
# use tradingagents
#
# # 创建应用用户（可选，用于更细粒度的权限控制）
# db.createUser({
#   user: "tradingagents_user",
#   pwd: "tradingagents123",
#   roles: [
# { role: "readWrite", db: "tradingagents"}
# ]
# })
# python scripts/import_config_and_create_user.py --host

# %%
# %%bash
# # 启动后端服务
# python -m app
# cd frontend
#
# # 启动开发服务器
# npm run dev
