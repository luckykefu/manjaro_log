# %%
# %cd /data/projects_ING

# %%
# !git clone https://github.com/TauricResearch/TradingAgents.git
# %cd TradingAgents

# %% [markdown]
# ## 创建conda 环境

# %%
# %%bash
# conda env list | grep -q "^TradingAgents " || conda create --name TradingAgents python=3.13 ipykernel -y

# %% [markdown]
# ## 安装依赖

# %%
# %cd /data/projects_ING/TradingAgents

# %pip install -r requirements.txt
