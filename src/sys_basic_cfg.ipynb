# %% [markdown]
# ## system basic config

# %%
# %cd /data/.manjaro

# %% [markdown]
# ## [zshrc](zshrc.ipynb)

# %% [markdown]
# ## [homelinks](homelinks.ipynb)

# %% [markdown]
# ## [vscode](vscode.ipynb)

# %% [markdown]
# ### [gpg](gpg.ipynb)

# %% [markdown]
# ## [pacman](pacman.ipynb)

# %% [markdown]
# ## yay

# %%
# %%bash
# sudo pacman -Sy --needed --noconfirm base-devel yay uv

# %% [markdown]
# ## pacman-key

# %%
# %%bash
# echo "installing pacman-key..."
# sudo pacman -S --needed --noconfirm manjaro-keyring archlinux-keyring archlinuxcn-keyring
# sudo pacman-key --init
# sudo pacman-key --populate archlinux manjaro archlinuxcn
# sudo pacman -Syy --noconfirm

# %% [markdown]
# ## update system

# %%
# %%bash
# sudo pacman -Syyu --noconfirm

# %%
# %%bash
# yay -Syyu --noconfirm

# %%
# %%bash
# yay -S --needed --noconfirm visual-studio-code-bin cryptomator-bin google-chrome  clash-verge-rev-bin keepassxc

# %%
# cryptomator
# /data/.cryptomator

# keepassxc
# /data/.manjaro/backup_data

# clash-verge
# sub link : https://zhuzhuzhu.whtjdasha.com/api/v1/client/subscribe?token=eebe36f8c2eb695b9841a61eb4b03825
# setting : auto start; slient start ; allow lan;

# %%
# %%bash
# i=$(ip addr show | grep -E 'inet.*global' | awk '{print $2}' | cut -d'/' -f1 | head -n1) && echo "Using IP: $i "
# google-chrome-stable --proxy-server="socks5://${i}:7897" &
#
# # chrome
# # kefu1820@gmail.com

# %% [markdown]
# ## [Git](git.ipynb)

# %% [markdown]
# ## [SSH](ssh.ipynb)

# %% [markdown]
# ## 配置自动启动

# %%
# %%bash
# add_autostart() {
#     local app="$1"
#     local autostart_dir="$HOME/.config/autostart"
#     mkdir -p "$autostart_dir"
#
#     local exec_path=$(which "$app")
#
#     if [[ -n "$exec_path" ]]; then
#         cat > "$autostart_dir/$app.desktop" <<EOF
# [Desktop Entry]
# Type=Application
# Name=$app
# Exec=$exec_path
# Icon=$app
# Comment=Auto-start $app
# X-GNOME-Autostart-enabled=true
# StartupNotify=false
# Terminal=false
# EOF
#         echo "✓ Created autostart for $app"
#     else
#         echo "✗ Failed to find $app"
#     fi
# }
#
# # >>>>>>>>>>>>>>>>>>>>使用示例>>>>>>>>>>>>>>>
# add_autostart "cryptomator"
# add_autostart  "keepassxc"

# %% [markdown]
# ## [amd gpu](amd_gpu.ipynb)

# %%
# %%bash
# sudo mkdir -p /opt/amdgpu/share/libdrm
# sudo ln -sf /usr/share/libdrm/amdgpu.ids /opt/amdgpu/share/libdrm/amdgpu.ids

# %% [markdown]
# ## [fcixt5](fcixt5.ipynb)

# %%
# %%bash
# sudo pacman -S --needed --noconfirm \
# 	fcitx5 \
# 	fcitx5-gtk \
# 	fcitx5-qt \
# 	fcitx5-configtool \
# 	fcitx5-chinese-addons \
# 	fcitx5-pinyin-zhwiki
# kwriteconfig6 --file kwinrc --group Wayland --key 'InputMethod' /usr/share/applications/org.fcitx.Fcitx5.desktop
# Out:
# warning: fcitx5-5.1.17-1 is up to date -- skipping
# warning: fcitx5-gtk-5.1.5-1 is up to date -- skipping
# warning: fcitx5-qt-5.1.12-2 is up to date -- skipping
# warning: fcitx5-configtool-5.1.12-1 is up to date -- skipping
# warning: fcitx5-chinese-addons-5.1.11-1 is up to date -- skipping
# warning: fcitx5-pinyin-zhwiki-1:0.3.0.20251223-1 is up to date -- skipping
#  there is nothing to do

# %% [markdown]
# ssc
