# %%
# %%bash
# pacman -S --needed --noconfirm \
#     mesa \
#     lib32-mesa \
#     vulkan-radeon \
#     lib32-vulkan-radeon \
#     libva-mesa-driver \
#     lib32-libva-mesa-driver \
#     xf86-video-amdgpu \
#     rocm-opencl-runtime \
#     rocm-hip-runtime
